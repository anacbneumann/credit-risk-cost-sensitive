# %% [markdown]
# ## Mean Header:

# %% [markdown]
# <!-- =========================
#      NOTEBOOK HEADER TEMPLATE
#      ========================= -->
#
# <div style="
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
#   background: linear-gradient(90deg, #EE7F2D 0%, #FFB56B 100%);
#   color: #ffffff;
#   padding: 18px 22px;
#   border-radius: 14px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.18);
#   margin: 10px 0 14px 0;
# ">
#   <div style="
#     display:inline-block;
#     font-size: 12px;
#     letter-spacing: .12em;
#     text-transform: uppercase;
#     opacity: .92;
#     background: rgba(255,255,255,0.16);
#     padding: 6px 10px;
#     border-radius: 999px;
#     margin-bottom: 10px;
#   ">
#     Give Me Some Credit • <span style="font-weight:700;">NOTEBOOK MODULE NAME</span>
#   </div>
#
#   <div style="
#     font-size: 30px;
#     font-weight: 800;
#     line-height: 1.15;
#     margin: 6px 0 6px 0;
#   ">
#     NOTEBOOK HEADLINE (CLEAR + PURPOSEFUL)
#   </div>
#
#   <div style="
#     font-size: 15px;
#     line-height: 1.5;
#     opacity: .95;
#     max-width: 980px;
#   ">
#     ONE-SENTENCE GOAL. Example: We analyze <b>cs-training.csv</b> to validate data quality, profile key features, and define decisions that will guide modeling and threshold selection.
#   </div>
#
#   <div style="
#     margin-top: 12px;
#     font-size: 12px;
#     opacity: .92;
#     background: rgba(255,255,255,0.14);
#     display: inline-flex;
#     gap: 10px;
#     padding: 7px 10px;
#     border-radius: 10px;
#     border: 1px solid rgba(255,255,255,0.10);
#   ">
#     <span><b>Dataset:</b> DATASET NAME</span>
#     <span>•</span>
#     <span><b>Model:</b> Logistic Regression</span>
#     <span>•</span>
#     <span><b>Metric:</b> ROC/AUC + Cost</span>
#   </div>
# </div>
#
# <!-- =========================
#      SECTION CARD (CHECKLIST)
#      ========================= -->
# <div style="
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
#   background: #5B4661;
#   border: 1px solid rgba(255,255,255,0.18);
#   color: #ffffff;
#   padding: 14px 16px;
#   border-radius: 12px;
#   margin: 0 0 10px 0;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.18);
# ">
#   <div style="
#     font-weight: 800;
#     margin-bottom: 8px;
#     letter-spacing: .02em;
#   ">
#     What we’ll cover
#   </div>
#
#   <ul style="
#     margin: 0 0 0 18px;
#     line-height: 1.65;
#   ">
#     <li>ITEM 1</li>
#     <li>ITEM 2</li>
#     <li>ITEM 3</li>
#     <li>ITEM 4</li>
#   </ul>
#
#   <div style="
#     margin-top: 12px;
#     padding-top: 12px;
#     border-top: 1px solid rgba(255,255,255,0.14);
#     font-size: 13px;
#     opacity: 0.95;
#   ">
#     <b>Deliverable:</b> One-line outcome (e.g., a cleaned dataset + documented assumptions + baseline metrics).
#   </div>
# </div>

# %% [markdown]
# ## Auxiliar Header:

# %% [markdown]
# <div style="
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
#   background: linear-gradient(90deg, #5B4661 0%, #918395 100%);
#   color: #ffffff;
#   padding: 16px 20px;
#   border-radius: 14px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.18);
#   margin: 14px 0 12px 0;
# ">
#   <div style="
#     display:inline-block;
#     font-size: 12px;
#     letter-spacing: .12em;
#     text-transform: uppercase;
#     opacity: .92;
#     background: rgba(255,255,255,0.16);
#     padding: 6px 10px;
#     border-radius: 999px;
#     margin-bottom: 10px;
#   ">
#     SECTION NAME
#   </div>
#
#   <div style="
#     font-size: 22px;
#     font-weight: 800;
#     line-height: 1.2;
#     margin: 0 0 6px 0;
#   ">
#     Section headline (optional)
#   </div>
#
#   <div style="
#     font-size: 13px;
#     line-height: 1.5;
#     opacity: .92;
#     max-width: 980px;
#   ">
#     One-line purpose for this section (optional).
#   </div>
# </div>

# %% [markdown]
# <!-- Subsection header (ultra-compact) -->
# <div style="
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
#   background: #5B4661;
#   border: 1px solid rgba(255,255,255,0.18);
#   color: #ffffff;
#   padding: 8px 12px;
#   border-radius: 12px;
#   margin: 10px 0 12px 0;
# ">
#   <div style="
#     font-size: 12px;
#     letter-spacing: .12em;
#     text-transform: uppercase;
#     opacity: .92;
#     font-weight: 800;
#   ">
#     Header 2
#   </div>
# </div>

# %% [markdown]
# <!-- Note / comment box (minimal) -->
# <div style="
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
#   background: rgba(170,170,170,0.10);
#   border: 1px solid rgba(170,170,170,0.22);
#   color: rgba(255,255,255,0.82);
#   padding: 10px 12px;
#   border-radius: 12px;
#   margin: 10px 0 12px 0;
# ">
#   <div style="
#     font-size: 12px;
#     letter-spacing: .10em;
#     text-transform: uppercase;
#     opacity: .75;
#     font-weight: 800;
#     margin-bottom: 6px;
#   ">
#     Note
#   </div>
#   <div style="font-size: 13px; line-height: 1.55;">
#     <!-- Write your comment here -->
#     This block checks column types and gives a quick overview of the dataset structure.
#   </div>
# </div>

# %% [markdown]
# <!-- Note / comment box (ultra-discreet) -->
# <div style="
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
#   background: rgba(170,170,170,0.08);
#   border-left: 4px solid #AAAAAA;
#   color: rgba(255,255,255,0.78);
#   padding: 10px 12px;
#   border-radius: 10px;
#   margin: 10px 0 12px 0;
# ">
#   <div style="font-size: 13px; line-height: 1.55;">
#     <!-- Write your comment here -->
#     Quick note: `str()` shows variable types + a compact preview of values.
#   </div>
# </div>
